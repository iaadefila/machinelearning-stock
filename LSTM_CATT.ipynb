# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 71kB 2.6MB/s
#   Building wheel for keras-tuner (setup.py) ... done
#   Building wheel for terminaltables (setup.py) ... done

# %%
# Import required packages, libraries and classes for the project

import numpy as np
np.random.seed(1)

import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential, load_model
from keras.layers.core import Dense
from keras.layers.recurrent import LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
import datetime as dt
import time
import keras
plt.style.use('default')
from keras.layers import Dense, Dropout
import kerastuner as kt

# %% [markdown]
# ### Data Preprocessing

# %%
# Load the Dataset
df = pd.read_csv("/content/drive/My Drive/stockCATT.csv",parse_dates = True,index_col=0)
df.head()
# Out:
#              Open   High    Low  ...       STOCH     STOCHD  Close
# Date                             ...
# 2014-06-25  246.0  246.0  238.0  ...   80.952381  85.807656  238.0
# 2014-06-26  228.0  238.0  228.0  ...   94.117647  92.156863  236.0
# 2014-06-30  234.0  234.0  232.0  ...   82.352941  92.156863  232.0
# 2014-07-02  224.0  238.0  224.0  ...  100.000000  98.039216  238.0
# 2014-07-03  228.0  228.0  228.0  ...   94.117647  89.705882  228.0
#
# [5 rows x 15 columns]

# %%
# Correlation Matrix
df.corr()['Close']
# Out:
# Open       0.991557
# High       0.997188
# Low        0.992472
# Volume    -0.056827
# SMA        0.966160
# EMA        0.973782
# MOM        0.182838
# RSI        0.369130
# ROC        0.231322
# MACD       0.318521
# BB         0.967725
# CHAIKIN    0.017259
# STOCH      0.220626
# STOCHD     0.222055
# Close      1.000000
# Name: Close, dtype: float64

# %%
# Extracting the features for the LSTM model
series = df[["Close",	"MOM",	"RSI",	"ROC",	"MACD",	"BB",	"CHAIKIN",	"STOCH"]]
print(series.shape)
series.head()
# Out:
# (1053, 8)
#             Close   MOM        RSI  ...     BB       CHAIKIN       STOCH
# Date                                ...
# 2014-06-25  238.0  34.0  67.266588  ...  216.6  8.282992e+05   80.952381
# 2014-06-26  236.0  28.0  66.497705  ...  215.1  9.957417e+05   94.117647
# 2014-06-30  232.0  22.0  64.928560  ...  213.4  1.147855e+06   82.352941
# 2014-07-02  238.0  34.0  69.584450  ...  212.2  1.319687e+06  100.000000
# 2014-07-03  228.0  22.0  65.677831  ...  210.6  1.019886e+06   94.117647
#
# [5 rows x 8 columns]

# %%
# Normalisation
sc_X = StandardScaler()
series.iloc[:,1:] = sc_X.fit_transform(series.iloc[:,1:])
sc_y = StandardScaler()
series[['Close']] = sc_y.fit_transform(series[['Close']])
series
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3076: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.iloc._setitem_with_indexer((slice(None), indexer), value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3041: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_array(key, value)
#                Close       MOM       RSI  ...        BB   CHAIKIN     STOCH
# Date                                      ...
# 2014-06-25  1.293529  2.375617  1.953647  ...  0.817584 -0.249197  0.659242
# 2014-06-26  1.246472  1.951390  1.862613  ...  0.781434 -0.186898  1.034633
# 2014-06-30  1.152358  1.527163  1.676831  ...  0.740465 -0.130302  0.699178
# 2014-07-02  1.293529  2.375617  2.228075  ...  0.711545 -0.066370  1.202361
# 2014-07-03  1.058244  1.527163  1.765543  ...  0.672985 -0.177915  1.034633
# ...              ...       ...       ...  ...       ...       ...       ...
# 2020-05-03 -0.094650 -0.452562 -0.928734  ...  0.069283  1.445508 -1.348868
# 2020-05-04  0.093578  0.042369  0.455086  ...  0.070488  1.252545 -0.148290
# 2020-05-05  0.164163  0.678709  1.151631  ...  0.062053 -0.166717  0.301927
# 2020-05-06  0.234748  0.890823  1.970488  ...  0.050003 -0.069418  0.752144
# 2020-05-07  0.281805  0.749414  2.595188  ...  0.039158  0.100849  1.202361
#
# [1053 rows x 8 columns]

# %%
series.tail()
# Out:
#                Close       MOM       RSI  ...        BB   CHAIKIN     STOCH
# Date                                      ...
# 2020-05-03 -0.094650 -0.452562 -0.928734  ...  0.069283  1.445508 -1.348868
# 2020-05-04  0.093578  0.042369  0.455086  ...  0.070488  1.252545 -0.148290
# 2020-05-05  0.164163  0.678709  1.151631  ...  0.062053 -0.166717  0.301927
# 2020-05-06  0.234748  0.890823  1.970488  ...  0.050003 -0.069418  0.752144
# 2020-05-07  0.281805  0.749414  2.595188  ...  0.039158  0.100849  1.202361
#
# [5 rows x 8 columns]

# %%
# Train/Test Data Split
train_start = dt.date(2014,5,15)
train_end = dt.date(2020,3,1)
train_data = series.loc[train_start:train_end]

test_start = dt.date(2020,3,2)
test_end = dt.date(2020,6,14)
test_data = series.loc[test_start:test_end]

print(train_data.shape,test_data.shape)
# Out:
# (1006, 8) (47, 8)

# %%
train = train_data.values
val = test_data.values

# %%
# Setting up an Early Stopping function
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')
callbacks_list = [earlystop]
RMSE = keras.metrics.RootMeanSquaredError()

# %%
#Build and train the model
def fit_model(train,val,timesteps,lr,batch,epochs,dropout,units):
    X_train = []
    Y_train = []
    X_val = []
    Y_val = []
    hl = units
    # Loop for training data
    for i in range(timesteps,train.shape[0]):
        X_train.append(train[i-timesteps:i])
        Y_train.append(train[i][0])
    X_train,Y_train = np.array(X_train),np.array(Y_train)
  
    # Loop for val data
    for i in range(timesteps,val.shape[0]):
        X_val.append(val[i-timesteps:i])
        Y_val.append(val[i][0])
    X_val,Y_val = np.array(X_val),np.array(Y_val)
    
    # Adding Layers to the model
    model = Sequential()
    model.add(LSTM(X_train.shape[2],input_shape = (X_train.shape[1],X_train.shape[2]),return_sequences = True,
                   activation = 'relu'))
    for i in range(len(hl)-1):        
        model.add(LSTM(hl[i],activation = 'relu',return_sequences = True))
    model.add(LSTM(hl[-1],activation = 'relu'))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    model.compile(optimizer = optimizers.Adam(lr = lr), loss = 'mean_squared_error',
                  metrics=[RMSE,'mse', 'mae', 'mape'])
    #print(model.summary())
  
    # Training the data
    history = model.fit(X_train,Y_train,epochs = epochs,batch_size = batch,
                        validation_data = (X_val, Y_val),verbose = 2,
                        shuffle = False, callbacks=callbacks_list)
    mse = history.history['val_mse'][-1]
    mae = history.history['val_mae'][-1]
    mape = history.history['val_mape'][-1]
    rmse = history.history["val_root_mean_squared_error"][-1]
    model.reset_states()
    return model, history.history['loss'], history.history['val_loss'],\
     rmse, mse, mae, mape

# %%
X_train = []
Y_train = []
X_val = []
Y_val = []
timesteps = 45
# Loop for training data
for i in range(timesteps,train.shape[0]):
    X_train.append(train[i-timesteps:i])
    Y_train.append(train[i][0])
X_train,Y_train = np.array(X_train),np.array(Y_train)

# Loop for val data
for i in range(timesteps,val.shape[0]):
    X_val.append(val[i-timesteps:i])
    Y_val.append(val[i][0])
X_val,Y_val = np.array(X_val),np.array(Y_val)

# %%
from keras import backend as K
from keras.losses import mean_squared_error

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(mean_squared_error(y_true, y_pred))

# %%
def model_builder(hp):
  # Define the ConvLSTM Model
  model = keras.Sequential()
  model.add(LSTM(X_train.shape[2],input_shape = (X_train.shape[1],X_train.shape[2]),return_sequences = True,
                   activation = 'relu'))

  # Tune the number of units in the first Dense layer
  hp_units = hp.Int('units', min_value = 16, max_value = 64, step = 8)
  model.add(LSTM(units = hp_units,activation = 'relu',return_sequences = True))
  model.add(LSTM(units = hp_units,activation = 'relu'))

  hp_dropout = hp.Float('dropout', min_value = .2, max_value = .5, step = .1)
  model.add(Dropout(rate = hp_dropout))
  model.add(Dense(1))
  # Tune the learning rate for the optimizer 
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4]) 
  hp_batch = hp.Choice('batch_size', values = [8,16,64])

  model.compile(optimizer = optimizers.Adam(learning_rate = hp_learning_rate),
                loss = root_mean_squared_error,
                metrics=[root_mean_squared_error,'mse', 'mae', 'mape'])
  
  return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective = 'val_loss', 
                     max_epochs = 50,
                     factor = 3,
                     directory = 'my_dir',
                     project_name = 'intro_to_kt')

# %%
import tensorflow as tf
import IPython
class ClearTrainingOutput(tf.keras.callbacks.Callback):
  def on_train_end(*args, **kwargs):
    IPython.display.clear_output(wait = True)

# %%
tuner.search(X_train, Y_train, epochs = 10, validation_data = (X_val, Y_val), callbacks = [ClearTrainingOutput()])
# Out:
# Trial 90 Complete [00h 01m 54s]
# val_loss: 0.17590245604515076
#
# Best val_loss So Far: 0.0007150694727897644
# Total elapsed time: 00h 35m 18s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]

print(f"""
The hyperparameter search is complete.\nThe optimal number of units in the first densely-connected layer is {best_hps.get('units')}\n
The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}\n
The best dropout is {best_hps.get('dropout')}\n
The best batch size is {best_hps.get('batch_size')}\n
The best num of epochs is {best_hps.get('tuner/epochs')}.
""")
# Out:
# The hyperparameter search is complete.
# The optimal number of units in the first densely-connected layer is 48
#
# The optimal learning rate for the optimizer is 0.01
#
# The best dropout is 0.4000000000000001
#
# The best batch size is 16
#
# The best num of epochs is 50.

# %%
tuner.results_summary(num_trials=90)
# Out:
# Results summary
# Results in my_dir/intro_to_kt
# Showing 90 best trials
# Objective(name='val_loss', direction='min')
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 16
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: b3780e4a673b60292c44cba37d9894b1
# Score: 0.0007150694727897644
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.003461681306362152
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 1c9eddbe0fe3f2da7ae1fbefcf4f4a70
# Score: 0.004762567579746246
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 16
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.00563947856426239
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 4aeb5aa5abb51f87fe1e1bdff83af8a1
# Score: 0.006436675786972046
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.006604142487049103
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.30000000000000004
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: d78058aeb01dc6ae4b7f8b085c614e5d
# Score: 0.008131913840770721
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.5000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: c0daf4dc6ea3dc2e3c3ff7dc01ed9aa5
# Score: 0.008763164281845093
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.010908588767051697
# Trial summary
# Hyperparameters:
# units: 16
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.014690592885017395
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 011ca77f084bb24c27b1127b5660d5ee
# Score: 0.020854569971561432
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.02153489738702774
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.5000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 7546f69f11df7dcab06ebdf4606c1df6
# Score: 0.02165883034467697
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.022733397781848907
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.5000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 5efb00cf9dab49419fee8260d5024259
# Score: 0.023014672100543976
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.5000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.024666301906108856
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.02479717880487442
# Trial summary
# Hyperparameters:
# units: 16
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 1cc34194d468f63ac595260068fe0e6e
# Score: 0.02560190111398697
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.30000000000000004
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 5728d8842b3648e886abc728ce441dc2
# Score: 0.026895679533481598
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.2
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.03400007635354996
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 16
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.035096652805805206
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.5000000000000001
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.03522384911775589
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 6dc526667baa2e2a013b56cf0c73c9ac
# Score: 0.03776472061872482
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.05100301653146744
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 2d9a221e63b48958b13d6144c9c9a10c
# Score: 0.05231987684965134
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 646e34358b24b367669e34931336e0f9
# Score: 0.05541928857564926
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.30000000000000004
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.059558331966400146
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: a281493c3709e3e7ec6c53a03caf40e6
# Score: 0.06212244927883148
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 175dbfc2f460438890e05bb58dec2a4a
# Score: 0.0675635114312172
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.30000000000000004
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.06924713402986526
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.5000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 6880a0c439c3bdf245f4ec63f525274e
# Score: 0.0695209875702858
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.5000000000000001
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.08149665594100952
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 9da8b29a431a90db9c2d06e1137c085d
# Score: 0.0825803279876709
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.2
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: 38530b7696acf5b2320b3fbd5dddc218
# Score: 0.08890949189662933
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.09253998845815659
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.30000000000000004
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.09287136048078537
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: a4b0b0f62af4de06901515969ee2ca0c
# Score: 0.09310629218816757
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.09375735372304916
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.30000000000000004
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: c78ebbdd770f6dc7db0668c33fd28bfa
# Score: 0.09480477124452591
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: ea1b8f1fadd3ba62426ddaa4a945d075
# Score: 0.0973709300160408
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.11355658620595932
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.12394420802593231
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.30000000000000004
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.12403598427772522
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.5000000000000001
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: dc63cc5633ed1ca4114da7c12022cb2f
# Score: 0.1419461965560913
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.142853245139122
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.5000000000000001
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.14426776766777039
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.5000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.14689995348453522
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.15290144085884094
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.5000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.16463077068328857
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.2
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.16796445846557617
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.2
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.16942870616912842
# Trial summary
# Hyperparameters:
# units: 16
# dropout: 0.30000000000000004
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.17431610822677612
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.17590245604515076
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.5000000000000001
# learning_rate: 0.0001
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.18642139434814453
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.5000000000000001
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.1884172260761261
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.30000000000000004
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0607e5fce805311579ab596eb5423da2
# Score: 0.1986549347639084
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.2052227258682251
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.5000000000000001
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.20651501417160034
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.30000000000000004
# learning_rate: 0.0001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.20745119452476501
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.0001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.22063207626342773
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.5000000000000001
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.22260993719100952
# Trial summary
# Hyperparameters:
# units: 16
# dropout: 0.4000000000000001
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.22261366248130798
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.2
# learning_rate: 0.0001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.2234080731868744
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.22369658946990967
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.2
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.22673122584819794
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.2
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.22817380726337433
# Trial summary
# Hyperparameters:
# units: 16
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.23018766939640045
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.5000000000000001
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 6
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.23040933907032013
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.4000000000000001
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.2352416068315506
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: dbec853d1034d84b4246679bf6f9f8fa
# Score: 0.2371266484260559
# Trial summary
# Hyperparameters:
# units: 16
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.2446231096982956
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.2
# learning_rate: 0.01
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.24635298550128937
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.2
# learning_rate: 0.0001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.2498144805431366
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.2521262764930725
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 4bbe25c45f3d5b22d0a25969afbc5039
# Score: 0.25778698921203613
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 6
# tuner/initial_epoch: 2
# tuner/bracket: 3
# tuner/round: 1
# tuner/trial_id: aa7d411f52e0cc91d11bb2cfae8f8fda
# Score: 0.2584412395954132
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.30000000000000004
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 50
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.26245811581611633
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.4000000000000001
# learning_rate: 0.0001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.27218863368034363
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.30000000000000004
# learning_rate: 0.01
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.2864088714122772
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.4000000000000001
# learning_rate: 0.0001
# batch_size: 16
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.2963009178638458
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.307327538728714
# Trial summary
# Hyperparameters:
# units: 16
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.3085957169532776
# Trial summary
# Hyperparameters:
# units: 32
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.33212023973464966
# Trial summary
# Hyperparameters:
# units: 24
# dropout: 0.30000000000000004
# learning_rate: 0.001
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.3414364457130432
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.4000000000000001
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.3624361455440521
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.4000000000000001
# learning_rate: 0.0001
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.3865432143211365
# Trial summary
# Hyperparameters:
# units: 48
# dropout: 0.5000000000000001
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 6
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 06a8d3809c6d00ac89cd6fa3fafb4a4e
# Score: 0.45568522810935974
# Trial summary
# Hyperparameters:
# units: 40
# dropout: 0.2
# learning_rate: 0.001
# batch_size: 16
# tuner/epochs: 17
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5298799872398376
# Trial summary
# Hyperparameters:
# units: 64
# dropout: 0.4000000000000001
# learning_rate: 0.01
# batch_size: 8
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.7644903659820557
# Trial summary
# Hyperparameters:
# units: 56
# dropout: 0.4000000000000001
# learning_rate: 0.001
# batch_size: 8
# tuner/epochs: 50
# tuner/initial_epoch: 17
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: ba4062a7ba10897798478e8ce90f5cc8
# Score: nan

# %%
model = tuner.hypermodel.build(best_hps)
model.fit(X_train, Y_train, epochs = 50, validation_data = (X_val, Y_val))
# Out:
# Epoch 1/50
# 31/31 [==============================] - 6s 77ms/step - loss: 20.0410 - root_mean_squared_error: 20.0410 - mse: 62990.4723 - mae: 20.0410 - mape: 2692.6125 - val_loss: 0.3848 - val_root_mean_squared_error: 0.3848 - val_mse: 0.1489 - val_mae: 0.3848 - val_mape: 149.2225
# Epoch 2/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.5170 - root_mean_squared_error: 0.5170 - mse: 0.4990 - mae: 0.5170 - mape: 1101.6375 - val_loss: 0.8143 - val_root_mean_squared_error: 0.8143 - val_mse: 0.6643 - val_mae: 0.8143 - val_mape: 316.6246
# Epoch 3/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.4000 - root_mean_squared_error: 0.4000 - mse: 0.2759 - mae: 0.4000 - mape: 2813.3689 - val_loss: 0.6369 - val_root_mean_squared_error: 0.6369 - val_mse: 0.4068 - val_mae: 0.6369 - val_mape: 247.4855
# Epoch 4/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.4146 - root_mean_squared_error: 0.4146 - mse: 0.3061 - mae: 0.4146 - mape: 1668.3416 - val_loss: 0.6661 - val_root_mean_squared_error: 0.6661 - val_mse: 0.4446 - val_mae: 0.6661 - val_mape: 258.9413
# Epoch 5/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.3509 - root_mean_squared_error: 0.3509 - mse: 0.2167 - mae: 0.3509 - mape: 1706.8044 - val_loss: 0.4884 - val_root_mean_squared_error: 0.4884 - val_mse: 0.2397 - val_mae: 0.4884 - val_mape: 189.4471
# Epoch 6/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2891 - root_mean_squared_error: 0.2891 - mse: 0.1426 - mae: 0.2891 - mape: 1034.5791 - val_loss: 0.1796 - val_root_mean_squared_error: 0.1796 - val_mse: 0.0332 - val_mae: 0.1796 - val_mape: 69.0307
# Epoch 7/50
# 31/31 [==============================] - 2s 59ms/step - loss: 0.2594 - root_mean_squared_error: 0.2594 - mse: 0.1217 - mae: 0.2594 - mape: 871.9633 - val_loss: 0.1004 - val_root_mean_squared_error: 0.1004 - val_mse: 0.0112 - val_mae: 0.1004 - val_mape: 38.0142
# Epoch 8/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.3093 - root_mean_squared_error: 0.3093 - mse: 0.1782 - mae: 0.3093 - mape: 743.1428 - val_loss: 0.2377 - val_root_mean_squared_error: 0.2377 - val_mse: 0.0573 - val_mae: 0.2377 - val_mape: 91.7906
# Epoch 9/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2692 - root_mean_squared_error: 0.2692 - mse: 0.1282 - mae: 0.2692 - mape: 1433.8108 - val_loss: 0.1407 - val_root_mean_squared_error: 0.1407 - val_mse: 0.0208 - val_mae: 0.1407 - val_mape: 53.8281
# Epoch 10/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2495 - root_mean_squared_error: 0.2495 - mse: 0.1095 - mae: 0.2495 - mape: 528.5614 - val_loss: 0.2153 - val_root_mean_squared_error: 0.2153 - val_mse: 0.0473 - val_mae: 0.2153 - val_mape: 83.0095
# Epoch 11/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2983 - root_mean_squared_error: 0.2983 - mse: 0.1631 - mae: 0.2983 - mape: 674.1768 - val_loss: 0.1894 - val_root_mean_squared_error: 0.1894 - val_mse: 0.0371 - val_mae: 0.1894 - val_mape: 72.7026
# Epoch 12/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2736 - root_mean_squared_error: 0.2736 - mse: 0.1409 - mae: 0.2736 - mape: 982.8837 - val_loss: 0.2051 - val_root_mean_squared_error: 0.2051 - val_mse: 0.0430 - val_mae: 0.2051 - val_mape: 78.9765
# Epoch 13/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2472 - root_mean_squared_error: 0.2472 - mse: 0.1115 - mae: 0.2472 - mape: 607.4906 - val_loss: 0.1577 - val_root_mean_squared_error: 0.1577 - val_mse: 0.0259 - val_mae: 0.1577 - val_mape: 60.4098
# Epoch 14/50
# 31/31 [==============================] - 2s 58ms/step - loss: 0.2617 - root_mean_squared_error: 0.2617 - mse: 0.1325 - mae: 0.2617 - mape: 491.3049 - val_loss: 0.1184 - val_root_mean_squared_error: 0.1184 - val_mse: 0.0152 - val_mae: 0.1184 - val_mape: 45.0264
# Epoch 15/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2323 - root_mean_squared_error: 0.2323 - mse: 0.1026 - mae: 0.2323 - mape: 571.1787 - val_loss: 0.0841 - val_root_mean_squared_error: 0.0841 - val_mse: 0.0083 - val_mae: 0.0841 - val_mape: 31.6150
# Epoch 16/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2570 - root_mean_squared_error: 0.2570 - mse: 0.1320 - mae: 0.2570 - mape: 497.0026 - val_loss: 0.0860 - val_root_mean_squared_error: 0.0860 - val_mse: 0.0087 - val_mae: 0.0860 - val_mape: 32.2852
# Epoch 17/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2434 - root_mean_squared_error: 0.2434 - mse: 0.1112 - mae: 0.2434 - mape: 415.4572 - val_loss: 0.1587 - val_root_mean_squared_error: 0.1587 - val_mse: 0.0262 - val_mae: 0.1587 - val_mape: 60.8374
# Epoch 18/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.3052 - root_mean_squared_error: 0.3052 - mse: 0.1867 - mae: 0.3052 - mape: 514.5411 - val_loss: 0.0962 - val_root_mean_squared_error: 0.0962 - val_mse: 0.0107 - val_mae: 0.0962 - val_mape: 36.2517
# Epoch 19/50
# 31/31 [==============================] - 2s 63ms/step - loss: 0.2526 - root_mean_squared_error: 0.2526 - mse: 0.1254 - mae: 0.2526 - mape: 548.9555 - val_loss: 0.0528 - val_root_mean_squared_error: 0.0528 - val_mse: 0.0042 - val_mae: 0.0528 - val_mape: 19.2615
# Epoch 20/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2808 - root_mean_squared_error: 0.2808 - mse: 0.1468 - mae: 0.2808 - mape: 516.6301 - val_loss: 0.0793 - val_root_mean_squared_error: 0.0793 - val_mse: 0.0077 - val_mae: 0.0793 - val_mape: 29.6481
# Epoch 21/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2541 - root_mean_squared_error: 0.2541 - mse: 0.1204 - mae: 0.2541 - mape: 369.3487 - val_loss: 0.0926 - val_root_mean_squared_error: 0.0926 - val_mse: 0.0099 - val_mae: 0.0926 - val_mape: 34.8703
# Epoch 22/50
# 31/31 [==============================] - 2s 65ms/step - loss: 0.2236 - root_mean_squared_error: 0.2236 - mse: 0.0924 - mae: 0.2236 - mape: 647.0160 - val_loss: 0.0355 - val_root_mean_squared_error: 0.0355 - val_mse: 0.0024 - val_mae: 0.0355 - val_mape: 15.0415
# Epoch 23/50
# 31/31 [==============================] - 2s 63ms/step - loss: 0.2378 - root_mean_squared_error: 0.2378 - mse: 0.1061 - mae: 0.2378 - mape: 678.7054 - val_loss: 0.0414 - val_root_mean_squared_error: 0.0414 - val_mse: 0.0029 - val_mae: 0.0414 - val_mape: 14.9719
# Epoch 24/50
# 31/31 [==============================] - 2s 66ms/step - loss: 0.2097 - root_mean_squared_error: 0.2097 - mse: 0.0883 - mae: 0.2097 - mape: 456.6294 - val_loss: 0.2695 - val_root_mean_squared_error: 0.2695 - val_mse: 0.0732 - val_mae: 0.2695 - val_mape: 104.3134
# Epoch 25/50
# 31/31 [==============================] - 2s 64ms/step - loss: 0.2287 - root_mean_squared_error: 0.2287 - mse: 0.0935 - mae: 0.2287 - mape: 539.1341 - val_loss: 0.0758 - val_root_mean_squared_error: 0.0758 - val_mse: 0.0068 - val_mae: 0.0758 - val_mape: 28.4193
# Epoch 26/50
# 31/31 [==============================] - 2s 64ms/step - loss: 0.2309 - root_mean_squared_error: 0.2309 - mse: 0.0997 - mae: 0.2309 - mape: 668.0569 - val_loss: 0.2027 - val_root_mean_squared_error: 0.2027 - val_mse: 0.0420 - val_mae: 0.2027 - val_mape: 78.0473
# Epoch 27/50
# 31/31 [==============================] - 2s 67ms/step - loss: 0.2305 - root_mean_squared_error: 0.2305 - mse: 0.1020 - mae: 0.2305 - mape: 565.0744 - val_loss: 0.1726 - val_root_mean_squared_error: 0.1726 - val_mse: 0.0308 - val_mae: 0.1726 - val_mape: 66.2414
# Epoch 28/50
# 31/31 [==============================] - 2s 63ms/step - loss: 0.2612 - root_mean_squared_error: 0.2612 - mse: 0.1220 - mae: 0.2612 - mape: 307.7929 - val_loss: 0.0308 - val_root_mean_squared_error: 0.0308 - val_mse: 0.0013 - val_mae: 0.0308 - val_mape: 11.3218
# Epoch 29/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2302 - root_mean_squared_error: 0.2302 - mse: 0.1100 - mae: 0.2302 - mape: 404.3416 - val_loss: 0.1437 - val_root_mean_squared_error: 0.1437 - val_mse: 0.0213 - val_mae: 0.1437 - val_mape: 55.1952
# Epoch 30/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2155 - root_mean_squared_error: 0.2155 - mse: 0.1019 - mae: 0.2155 - mape: 440.9013 - val_loss: 0.0599 - val_root_mean_squared_error: 0.0599 - val_mse: 0.0045 - val_mae: 0.0599 - val_mape: 22.3037
# Epoch 31/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2240 - root_mean_squared_error: 0.2240 - mse: 0.0904 - mae: 0.2240 - mape: 779.3395 - val_loss: 0.1129 - val_root_mean_squared_error: 0.1129 - val_mse: 0.0137 - val_mae: 0.1129 - val_mape: 42.9716
# Epoch 32/50
# 31/31 [==============================] - 2s 59ms/step - loss: 0.2204 - root_mean_squared_error: 0.2204 - mse: 0.0938 - mae: 0.2204 - mape: 290.1533 - val_loss: 0.1535 - val_root_mean_squared_error: 0.1535 - val_mse: 0.0244 - val_mae: 0.1535 - val_mape: 58.9083
# Epoch 33/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2457 - root_mean_squared_error: 0.2457 - mse: 0.1123 - mae: 0.2457 - mape: 436.2813 - val_loss: 0.1156 - val_root_mean_squared_error: 0.1156 - val_mse: 0.0142 - val_mae: 0.1156 - val_mape: 44.1011
# Epoch 34/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2324 - root_mean_squared_error: 0.2324 - mse: 0.1010 - mae: 0.2324 - mape: 578.3411 - val_loss: 0.1382 - val_root_mean_squared_error: 0.1382 - val_mse: 0.0199 - val_mae: 0.1382 - val_mape: 52.9466
# Epoch 35/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2115 - root_mean_squared_error: 0.2115 - mse: 0.0821 - mae: 0.2115 - mape: 542.5983 - val_loss: 0.0799 - val_root_mean_squared_error: 0.0799 - val_mse: 0.0073 - val_mae: 0.0799 - val_mape: 30.1079
# Epoch 36/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2278 - root_mean_squared_error: 0.2278 - mse: 0.1052 - mae: 0.2278 - mape: 806.6972 - val_loss: 0.1242 - val_root_mean_squared_error: 0.1242 - val_mse: 0.0165 - val_mae: 0.1242 - val_mape: 47.3171
# Epoch 37/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2143 - root_mean_squared_error: 0.2143 - mse: 0.0863 - mae: 0.2143 - mape: 307.4108 - val_loss: 0.0313 - val_root_mean_squared_error: 0.0313 - val_mse: 0.0010 - val_mae: 0.0313 - val_mape: 12.4660
# Epoch 38/50
# 31/31 [==============================] - 2s 59ms/step - loss: 0.2818 - root_mean_squared_error: 0.2818 - mse: 0.1956 - mae: 0.2818 - mape: 896.1776 - val_loss: 0.0522 - val_root_mean_squared_error: 0.0522 - val_mse: 0.0038 - val_mae: 0.0522 - val_mape: 19.2140
# Epoch 39/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2334 - root_mean_squared_error: 0.2334 - mse: 0.1022 - mae: 0.2334 - mape: 340.7615 - val_loss: 0.1713 - val_root_mean_squared_error: 0.1713 - val_mse: 0.0303 - val_mae: 0.1713 - val_mape: 65.7894
# Epoch 40/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2246 - root_mean_squared_error: 0.2246 - mse: 0.1024 - mae: 0.2246 - mape: 498.3606 - val_loss: 0.1210 - val_root_mean_squared_error: 0.1210 - val_mse: 0.0154 - val_mae: 0.1210 - val_mape: 46.2623
# Epoch 41/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2299 - root_mean_squared_error: 0.2299 - mse: 0.1030 - mae: 0.2299 - mape: 560.9399 - val_loss: 0.2195 - val_root_mean_squared_error: 0.2195 - val_mse: 0.0488 - val_mae: 0.2195 - val_mape: 84.8297
# Epoch 42/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2231 - root_mean_squared_error: 0.2231 - mse: 0.0929 - mae: 0.2231 - mape: 806.2002 - val_loss: 0.2115 - val_root_mean_squared_error: 0.2115 - val_mse: 0.0453 - val_mae: 0.2115 - val_mape: 81.7351
# Epoch 43/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2354 - root_mean_squared_error: 0.2354 - mse: 0.1079 - mae: 0.2354 - mape: 359.7293 - val_loss: 0.1706 - val_root_mean_squared_error: 0.1706 - val_mse: 0.0296 - val_mae: 0.1706 - val_mape: 65.7685
# Epoch 44/50
# 31/31 [==============================] - 2s 63ms/step - loss: 0.2184 - root_mean_squared_error: 0.2184 - mse: 0.0959 - mae: 0.2184 - mape: 568.4661 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1421 - val_mse: 0.0211 - val_mae: 0.1421 - val_mape: 54.4160
# Epoch 45/50
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2197 - root_mean_squared_error: 0.2197 - mse: 0.0895 - mae: 0.2197 - mape: 504.5802 - val_loss: 0.1219 - val_root_mean_squared_error: 0.1219 - val_mse: 0.0156 - val_mae: 0.1219 - val_mape: 46.6351
# Epoch 46/50
# 31/31 [==============================] - 2s 61ms/step - loss: 0.2185 - root_mean_squared_error: 0.2185 - mse: 0.0928 - mae: 0.2185 - mape: 459.6116 - val_loss: 0.1582 - val_root_mean_squared_error: 0.1582 - val_mse: 0.0258 - val_mae: 0.1582 - val_mape: 60.7725
# Epoch 47/50
# 31/31 [==============================] - 2s 63ms/step - loss: 0.2197 - root_mean_squared_error: 0.2197 - mse: 0.0892 - mae: 0.2197 - mape: 472.6210 - val_loss: 0.1259 - val_root_mean_squared_error: 0.1259 - val_mse: 0.0167 - val_mae: 0.1259 - val_mape: 48.1230
# Epoch 48/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2078 - root_mean_squared_error: 0.2078 - mse: 0.0818 - mae: 0.2078 - mape: 334.2313 - val_loss: 0.1393 - val_root_mean_squared_error: 0.1393 - val_mse: 0.0204 - val_mae: 0.1393 - val_mape: 53.3113
# Epoch 49/50
# 31/31 [==============================] - 2s 58ms/step - loss: 0.2221 - root_mean_squared_error: 0.2221 - mse: 0.0886 - mae: 0.2221 - mape: 282.6685 - val_loss: 0.2183 - val_root_mean_squared_error: 0.2183 - val_mse: 0.0481 - val_mae: 0.2183 - val_mape: 84.4556
# Epoch 50/50
# 31/31 [==============================] - 2s 62ms/step - loss: 0.2257 - root_mean_squared_error: 0.2257 - mse: 0.1042 - mae: 0.2257 - mape: 338.5162 - val_loss: 0.1093 - val_root_mean_squared_error: 0.1093 - val_mse: 0.0128 - val_mae: 0.1093 - val_mape: 41.6142

# %%
# Plotting the predictions
def plot_data(Y_test,Y_hat):
    plt.plot(Y_test,c = 'r')
    plt.plot(Y_hat,c = 'y')
    plt.xlabel('Day')
    plt.ylabel('Close')
    plt.title('Prediction Graph using Multivariate-LSTM model')
    plt.legend(['Actual','Predicted'],loc = 'lower right')
    plt.show()

# %%
# Plotting the training errors
def plot_loss(train_loss,val_loss):
    plt.plot(train_loss,c = 'r')
    plt.plot(val_loss,c = 'b')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend(['train','val'],loc = 'upper right')
    plt.show()

# %%
# Evaluating the model
def evaluate_model(model,test,timesteps):
    X_test = []
    Y_test = []

    # Loop for testing data
    for i in range(timesteps,test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test,Y_test = np.array(X_test),np.array(Y_test)
    
    # Prediction Time 
    Y_hat = model.predict(X_test)
    return Y_test, Y_hat

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 45, 8)             544
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 45, 48)            10944
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 48)                18624
# _________________________________________________________________
# dropout (Dropout)            (None, 48)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 49
# =================================================================
# Total params: 30,161
# Trainable params: 30,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = model.predict(X_val)
y_true = np.array([Y_val]).T

mae = tf.keras.losses.MeanAbsoluteError()
mae = mae(y_true, y_pred).numpy()

mape = tf.keras.losses.MeanAbsolutePercentageError()
mape = mape(y_true, y_pred).numpy()

mse = tf.keras.losses.MeanSquaredError()
mse = mse(y_true, y_pred).numpy()

rmse = sqrt(mse)

# %%
print('MSE = {}'.format(round(mse, 5)))
print('RMSE = {}'.format(round(rmse, 5)))
print('MAPE = {}'.format(round(mape, 5)))
print('MAE = {}'.format(round(mae, 5)))
# Out:
# MSE = 0.012839999981224537
# RMSE = 0.11332
# MAPE = 41.614219665527344
# MAE = 0.10931000113487244

# %%
true,predicted = evaluate_model(model,val,timesteps)

# %%
train_date = df['2014-05-15' : '2020-03-1'].index
test_date = df['2020-03-2' :].index
pred_date = df['2020-03-2' :].index[45:]

# %%
Y_train = sc_y.inverse_transform(np.array([train[:,0]]))
Y_test = sc_y.inverse_transform(np.array([val[:,0]]))
Y_pred = sc_y.inverse_transform(predicted.T)

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.figure(figsize=(16,8))
price_close_train = Y_train[0]
price_close_test = Y_test[0]
plt.plot(train_date, price_close_train, label = "Train Stock Price")
plt.plot(test_date, price_close_test, label = "Actual Stock Price")
plt.plot(pred_date, Y_pred[0], label = "Predicted Stock Price")

plt.title("Multivariate LSTM")
plt.legend(loc='upper left')
#plt.tight_layout()

plt.show()

# %%
# Save a model
model.save('MV-LSTM_dataset1_hyperband.h5')
